# %% [markdown]
# <a href="https://colab.research.google.com/github/haidaramumca/test/blob/main/wikiextract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import wikipedia
import spacy
nlp = spacy.load("en_core_web_sm")
result = wikipedia.search("Lionel Messi")
print(result)
page = wikipedia.page(result[1])

# get the whole wikipedia page text (content)
content = page.content

doc = nlp(content)

# Get all tokens and part-of-speech tags
token_texts = [token.text for token in doc]
pos_tags = [token.pos_ for token in doc]

for items in token_texts:
    # Check if the current token is a proper noun
    print(items)
# Out:
# ['Lionel Messi', 'List of international goals scored by Lionel Messi', 'Messi–Ronaldo rivalry', 'List of career achievements by Lionel Messi', 'Argentina national football team', 'New Maradona', 'Cristiano Ronaldo', 'List of FC Barcelona records and statistics', 'Messi (cougar)', 'Messi (2014 film)']
# Lionel
# Messi
# is
# an
# Argentine
# professional
# footballer
# who
# has
# represented
# the
# Argentina
# national
# football
# team
# as
# a
# forward
# since
# his
# debut
# in
# 2005
# .
# Since
# then
# ,
# Messi
# has
# scored
# 72
# goals
# in
# 144
# international
# appearances
# ,
# making
# him
# the
# country
# 's
# all
# -
# time
# top
# scorer
# ;
# he
# surpassed
# Gabriel
# Batistuta
# 's
# record
# of
# 54
# goals
# with
# a
# free
# kick
# against
# the
# United
# States
# in
# the
# semi
# -
# finals
# of
# the
# Copa
# América
# Centenario
# on
# 21
# June
# 2016
# .
# Messi
# made
# his
# debut
# for
# Argentina
# in
# a
# 2–1
# away
# win
# over
# Hungary
# on
# ...
